# %% [markdown]
# ## Neural Networks image recognition - MultiLayer Perceptron
# Use both MLNN for the following problem.
#
# 1. Add random noise (see below on `size parameter` on [`np.random.normal`](https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html)) to the images in training and testing. **Make sure each image gets a different noise feature added to it. Inspect by printing out several images. Note - the `size` parameter should match the data. **
# 2. Compare the `accuracy` of train and val after N epochs for MLNN with and without noise.
# 3. Vary the amount of noise by changing the `scale` parameter in `np.random.normal` by a factor. Use `.1, .5, 1.0, 2.0, 4.0` for the `scale` and keep track of the `accuracy` for training and validation and plot these results.

# %% [markdown]
# # `np.random.normal`
#
# ## Parameters
#
# ### loc
#
# Mean (“centre”) of the distribution.
#
# ### scale
#
# Standard deviation (spread or “width”) of the distribution. Must be non-negative.
#
# ### size
#
# Output shape. If the given shape is, e.g., (m, n, k), then m * n * k samples are drawn. If size is None (default), a single value is returned if loc and scale are both scalars. Otherwise, np.broadcast(loc, scale).size samples are drawn.

# %% [markdown]
# # Neural Networks - Image Recognition

# %%
# Importing necessary packages
import numpy as np
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt

# Loading and preprocessing the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

num_classes = 10

# Converting class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# Creating function to add noise to the images
def add_noise(x, scale):
    noise = np.random.normal(loc=0.0, scale=scale, size=x.shape)
    x_noisy = x + noise
    x_noisy = np.clip(x_noisy, 0., 1.)
    return x_noisy

# Creating function to create the MLP model
def create_mlp_model(input_shape, num_classes):
    model = Sequential()
    model.add(Dense(512, activation='relu', input_shape=input_shape))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(num_classes, activation='softmax'))
    return model

# Creating function to plot a grid of images
def plot_images(images, titles, ncols=5, nrows=5):
    fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(10, 10))
    for ax, img, title in zip(axes.ravel(), images, titles):
        ax.imshow(img.reshape(28, 28), cmap='gray')
        ax.set_title(title)
        ax.axis('off')
    plt.subplots_adjust(wspace=0.5, hspace=0.5)
    plt.show()

# Printing out images and noisy images 
def visualize_images(x, scale):
    x_noisy = add_noise(x, scale)
    
    # Select a subset of images to display
    indices = np.random.choice(x.shape[0], 25, replace=False)
    original_images = x[indices]
    noisy_images = x_noisy[indices]
    
    # Titles for visualization
    titles_original = ['Original'] * len(indices)
    titles_noisy = [f'Noisy (scale={scale:.1f})'] * len(indices)
    
    # Plot original images
    plot_images(original_images, titles_original, ncols=5, nrows=5)
    
    # Plot noisy images
    plot_images(noisy_images, titles_noisy, ncols=5, nrows=5)

# Defining noise scales for visualization
scales = [0.1, 0.5, 1.0, 2.0, 4.0]

# Visualizing images with different noise scales
for scale in scales:
    print(f'Visualizing images with noise scale {scale}...')
    visualize_images(x_train, scale)

# Training and evaluation
batch_size = 128
epochs = 20

results = []

for scale in scales:
    # Add noise to training and test data
    x_train_noisy = add_noise(x_train, scale)
    x_test_noisy = add_noise(x_test, scale)
    
    # Create and compile the model
    model = create_mlp_model((784,), num_classes)
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    # Train the model
    history = model.fit(x_train_noisy, y_train,
                        batch_size=batch_size,
                        epochs=epochs,
                        verbose=1,
                        validation_data=(x_test_noisy, y_test))
    
    # Evaluate the model
    score = model.evaluate(x_test_noisy, y_test, verbose=0)
    print(f'Scale {scale} - Test loss: {score[0]}, Test accuracy: {score[1]}')
    
    # Store results
    results.append((scale, history.history['accuracy'][-1], history.history['val_accuracy'][-1]))

# Convert the results to a numpy array for easier plotting
results = np.array(results)

# Plotting the results
plt.figure(figsize=(10, 5))
plt.plot(results[:, 0], results[:, 1], marker='o', label='Train Accuracy')
plt.plot(results[:, 0], results[:, 2], marker='o', label='Validation Accuracy')
plt.xlabel('Noise Scale')
plt.ylabel('Accuracy')
plt.title('Effect of Noise on Training and Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Visualizing images with noise scale 0.1...
# Visualizing images with noise scale 0.5...
# Visualizing images with noise scale 1.0...
# Visualizing images with noise scale 2.0...
# Visualizing images with noise scale 4.0...
# Epoch 1/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - accuracy: 0.8545 - loss: 0.4772 - val_accuracy: 0.9651 - val_loss: 0.1165
# Epoch 2/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.9639 - loss: 0.1193 - val_accuracy: 0.9710 - val_loss: 0.0933
# Epoch 3/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.9761 - loss: 0.0761 - val_accuracy: 0.9734 - val_loss: 0.0800
# Epoch 4/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.9830 - loss: 0.0540 - val_accuracy: 0.9774 - val_loss: 0.0745
# Epoch 5/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.9868 - loss: 0.0407 - val_accuracy: 0.9791 - val_loss: 0.0706
# Epoch 6/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.9883 - loss: 0.0366 - val_accuracy: 0.9786 - val_loss: 0.0737
# Epoch 7/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.9900 - loss: 0.0300 - val_accuracy: 0.9749 - val_loss: 0.0880
# Epoch 8/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.9905 - loss: 0.0279 - val_accuracy: 0.9759 - val_loss: 0.0880
# Epoch 9/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.9921 - loss: 0.0226 - val_accuracy: 0.9821 - val_loss: 0.0773
# Epoch 10/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.9935 - loss: 0.0188 - val_accuracy: 0.9792 - val_loss: 0.0813
# Epoch 11/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.9932 - loss: 0.0207 - val_accuracy: 0.9786 - val_loss: 0.0814
# Epoch 12/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.9922 - loss: 0.0255 - val_accuracy: 0.9775 - val_loss: 0.1031
# Epoch 13/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.9932 - loss: 0.0194 - val_accuracy: 0.9814 - val_loss: 0.0819
# Epoch 14/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.9951 - loss: 0.0153 - val_accuracy: 0.9800 - val_loss: 0.0912
# Epoch 15/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.9951 - loss: 0.0138 - val_accuracy: 0.9778 - val_loss: 0.1013
# Epoch 16/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.9940 - loss: 0.0173 - val_accuracy: 0.9797 - val_loss: 0.0941
# Epoch 17/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.9959 - loss: 0.0129 - val_accuracy: 0.9796 - val_loss: 0.0904
# Epoch 18/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.9957 - loss: 0.0132 - val_accuracy: 0.9802 - val_loss: 0.0923
# Epoch 19/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.9952 - loss: 0.0148 - val_accuracy: 0.9793 - val_loss: 0.0883
# Epoch 20/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.9956 - loss: 0.0130 - val_accuracy: 0.9776 - val_loss: 0.1071
# Scale 0.1 - Test loss: 0.10712934285402298, Test accuracy: 0.9775999784469604
# Epoch 1/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6985 - loss: 0.9007 - val_accuracy: 0.8746 - val_loss: 0.3965
# Epoch 2/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.8865 - loss: 0.3538 - val_accuracy: 0.8975 - val_loss: 0.3115
# Epoch 3/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.9228 - loss: 0.2372 - val_accuracy: 0.9145 - val_loss: 0.2701
# Epoch 4/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.9437 - loss: 0.1706 - val_accuracy: 0.9173 - val_loss: 0.2647
# Epoch 5/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.9552 - loss: 0.1338 - val_accuracy: 0.9173 - val_loss: 0.2752
# Epoch 6/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.9665 - loss: 0.1016 - val_accuracy: 0.9183 - val_loss: 0.2792
# Epoch 7/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.9746 - loss: 0.0774 - val_accuracy: 0.9185 - val_loss: 0.3005
# Epoch 8/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.9784 - loss: 0.0639 - val_accuracy: 0.9193 - val_loss: 0.3072
# Epoch 9/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.9824 - loss: 0.0544 - val_accuracy: 0.9197 - val_loss: 0.3322
# Epoch 10/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.9812 - loss: 0.0543 - val_accuracy: 0.9257 - val_loss: 0.3213
# Epoch 11/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.9843 - loss: 0.0458 - val_accuracy: 0.9227 - val_loss: 0.3383
# Epoch 12/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.9856 - loss: 0.0432 - val_accuracy: 0.9242 - val_loss: 0.3297
# Epoch 13/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.9869 - loss: 0.0378 - val_accuracy: 0.9208 - val_loss: 0.3759
# Epoch 14/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.9846 - loss: 0.0446 - val_accuracy: 0.9230 - val_loss: 0.3512
# Epoch 15/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.9878 - loss: 0.0367 - val_accuracy: 0.9270 - val_loss: 0.3751
# Epoch 16/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9899 - loss: 0.0306 - val_accuracy: 0.9259 - val_loss: 0.3920
# Epoch 17/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9882 - loss: 0.0348 - val_accuracy: 0.9231 - val_loss: 0.3673
# Epoch 18/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 17ms/step - accuracy: 0.9889 - loss: 0.0328 - val_accuracy: 0.9209 - val_loss: 0.4192
# Epoch 19/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.9897 - loss: 0.0311 - val_accuracy: 0.9233 - val_loss: 0.4004
# Epoch 20/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9891 - loss: 0.0318 - val_accuracy: 0.9234 - val_loss: 0.3903
# Scale 0.5 - Test loss: 0.39031192660331726, Test accuracy: 0.9233999848365784
# Epoch 1/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.4534 - loss: 1.5475 - val_accuracy: 0.6718 - val_loss: 0.9635
# Epoch 2/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.6744 - loss: 0.9535 - val_accuracy: 0.6932 - val_loss: 0.8948
# Epoch 3/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.7141 - loss: 0.8368 - val_accuracy: 0.7092 - val_loss: 0.8521
# Epoch 4/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.7466 - loss: 0.7423 - val_accuracy: 0.7190 - val_loss: 0.8182
# Epoch 5/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.7800 - loss: 0.6467 - val_accuracy: 0.7185 - val_loss: 0.8220
# Epoch 6/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.8079 - loss: 0.5697 - val_accuracy: 0.7346 - val_loss: 0.8170
# Epoch 7/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.8298 - loss: 0.4862 - val_accuracy: 0.7270 - val_loss: 0.8610
# Epoch 8/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.8498 - loss: 0.4330 - val_accuracy: 0.7254 - val_loss: 0.8730
# Epoch 9/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.8710 - loss: 0.3694 - val_accuracy: 0.7260 - val_loss: 0.9168
# Epoch 10/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.8880 - loss: 0.3188 - val_accuracy: 0.7250 - val_loss: 0.9495
# Epoch 11/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9005 - loss: 0.2861 - val_accuracy: 0.7254 - val_loss: 1.0279
# Epoch 12/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9085 - loss: 0.2570 - val_accuracy: 0.7176 - val_loss: 1.0758
# Epoch 13/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9210 - loss: 0.2237 - val_accuracy: 0.7236 - val_loss: 1.1245
# Epoch 14/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9279 - loss: 0.2028 - val_accuracy: 0.7206 - val_loss: 1.1708
# Epoch 15/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - accuracy: 0.9342 - loss: 0.1876 - val_accuracy: 0.7237 - val_loss: 1.1916
# Epoch 16/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9365 - loss: 0.1796 - val_accuracy: 0.7208 - val_loss: 1.1763
# Epoch 17/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9385 - loss: 0.1726 - val_accuracy: 0.7197 - val_loss: 1.2960
# Epoch 18/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9453 - loss: 0.1541 - val_accuracy: 0.7175 - val_loss: 1.2716
# Epoch 19/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9463 - loss: 0.1543 - val_accuracy: 0.7214 - val_loss: 1.3148
# Epoch 20/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9478 - loss: 0.1511 - val_accuracy: 0.7228 - val_loss: 1.3275
# Scale 1.0 - Test loss: 1.3275033235549927, Test accuracy: 0.7228000164031982
# Epoch 1/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - accuracy: 0.2098 - loss: 2.1501 - val_accuracy: 0.3711 - val_loss: 1.7945
# Epoch 2/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.3783 - loss: 1.7703 - val_accuracy: 0.3933 - val_loss: 1.7289
# Epoch 3/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.4134 - loss: 1.6871 - val_accuracy: 0.3987 - val_loss: 1.7262
# Epoch 4/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.4341 - loss: 1.6301 - val_accuracy: 0.4072 - val_loss: 1.7140
# Epoch 5/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.4556 - loss: 1.5781 - val_accuracy: 0.3958 - val_loss: 1.7448
# Epoch 6/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.4651 - loss: 1.5368 - val_accuracy: 0.4011 - val_loss: 1.7250
# Epoch 7/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.4845 - loss: 1.4906 - val_accuracy: 0.4032 - val_loss: 1.7310
# Epoch 8/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.4981 - loss: 1.4480 - val_accuracy: 0.4009 - val_loss: 1.7462
# Epoch 9/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.5136 - loss: 1.4008 - val_accuracy: 0.3903 - val_loss: 1.7638
# Epoch 10/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.5322 - loss: 1.3473 - val_accuracy: 0.3917 - val_loss: 1.8011
# Epoch 11/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.5508 - loss: 1.2896 - val_accuracy: 0.3860 - val_loss: 1.8323
# Epoch 12/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.5626 - loss: 1.2547 - val_accuracy: 0.3840 - val_loss: 1.8673
# Epoch 13/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.5781 - loss: 1.2049 - val_accuracy: 0.3788 - val_loss: 1.9037
# Epoch 14/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.5960 - loss: 1.1635 - val_accuracy: 0.3795 - val_loss: 1.9326
# Epoch 15/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.6104 - loss: 1.1145 - val_accuracy: 0.3753 - val_loss: 1.9806
# Epoch 16/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.6239 - loss: 1.0780 - val_accuracy: 0.3771 - val_loss: 2.0243
# Epoch 17/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.6287 - loss: 1.0480 - val_accuracy: 0.3773 - val_loss: 2.0464
# Epoch 18/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.6483 - loss: 1.0061 - val_accuracy: 0.3723 - val_loss: 2.1010
# Epoch 19/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.6567 - loss: 0.9706 - val_accuracy: 0.3658 - val_loss: 2.1419
# Epoch 20/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.6653 - loss: 0.9533 - val_accuracy: 0.3611 - val_loss: 2.1784
# Scale 2.0 - Test loss: 2.1783995628356934, Test accuracy: 0.3610999882221222
# Epoch 1/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 21ms/step - accuracy: 0.1167 - loss: 2.3211 - val_accuracy: 0.1742 - val_loss: 2.2369
# Epoch 2/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.1852 - loss: 2.2123 - val_accuracy: 0.2007 - val_loss: 2.1899
# Epoch 3/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.2109 - loss: 2.1702 - val_accuracy: 0.2124 - val_loss: 2.1689
# Epoch 4/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.2249 - loss: 2.1432 - val_accuracy: 0.2095 - val_loss: 2.1795
# Epoch 5/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.2308 - loss: 2.1264 - val_accuracy: 0.2079 - val_loss: 2.1750
# Epoch 6/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.2396 - loss: 2.1090 - val_accuracy: 0.2109 - val_loss: 2.1720
# Epoch 7/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.2435 - loss: 2.1042 - val_accuracy: 0.2176 - val_loss: 2.1634
# Epoch 8/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.2499 - loss: 2.0857 - val_accuracy: 0.2124 - val_loss: 2.1674
# Epoch 9/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.2589 - loss: 2.0720 - val_accuracy: 0.2129 - val_loss: 2.1776
# Epoch 10/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.2588 - loss: 2.0732 - val_accuracy: 0.2136 - val_loss: 2.1768
# Epoch 11/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.2598 - loss: 2.0641 - val_accuracy: 0.2112 - val_loss: 2.1784
# Epoch 12/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.2652 - loss: 2.0504 - val_accuracy: 0.2147 - val_loss: 2.1764
# Epoch 13/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.2683 - loss: 2.0426 - val_accuracy: 0.2140 - val_loss: 2.1830
# Epoch 14/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.2759 - loss: 2.0342 - val_accuracy: 0.2056 - val_loss: 2.1913
# Epoch 15/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.2689 - loss: 2.0367 - val_accuracy: 0.2058 - val_loss: 2.1956
# Epoch 16/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.2741 - loss: 2.0230 - val_accuracy: 0.2060 - val_loss: 2.1987
# Epoch 17/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.2827 - loss: 2.0081 - val_accuracy: 0.2062 - val_loss: 2.2021
# Epoch 18/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.2802 - loss: 2.0064 - val_accuracy: 0.2086 - val_loss: 2.1962
# Epoch 19/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.2837 - loss: 1.9980 - val_accuracy: 0.2034 - val_loss: 2.2103
# Epoch 20/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.2888 - loss: 1.9882 - val_accuracy: 0.2033 - val_loss: 2.2195
# Scale 4.0 - Test loss: 2.219526529312134, Test accuracy: 0.20329999923706055

# %% [markdown]
# **Interpretation:** As the graph showcases, the accuracy score of image detection steadily declines the more noise is added to each image. This is further confirmed by the images becoming increasingly unrecognizable with the addition of noise, where the numbers presented are hardly identifiable by the human eye.
